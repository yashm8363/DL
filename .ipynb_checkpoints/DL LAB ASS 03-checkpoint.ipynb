# %%
import numpy as np
import pandas as pd
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Conv2D,Dense,MaxPooling2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# # Loading and preparing the data

# %%
(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)
# (60000, 28, 28)

# %%
X_train[0].min(), X_train[0].max()
# Out:
# (0, 255)
# (0, 255)

# %%
X_train = (X_train - 0.0) / (255.0 - 0.0)
X_test = (X_test - 0.0) / (255.0 - 0.0)
X_train[0].min(), X_train[0].max()
# Out:
# (0.0, 1.0)
# (0.0, 1.0)

# %%
def plot_digit(image, digit, plt, i):
 plt.subplot(4, 5, i + 1)
 plt.imshow(image, cmap=plt.get_cmap('gray'))
 plt.title(f"Digit: {digit}")
 plt.xticks([])
 plt.yticks([])
plt.figure(figsize=(16, 10))
for i in range(20):
 plot_digit(X_train[i], y_train[i], plt, i) 
plt.show()

# %%
X_train = X_train.reshape((X_train.shape + (1,)))
X_test = X_test.reshape((X_test.shape + (1,)))
y_train[0:20]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9],
#       dtype=uint8)
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9],
#       dtype=uint8)

# %% [markdown]
# # Creating the Model

# %%
model = Sequential([
 Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
 MaxPooling2D((2, 2)),
 Flatten(),
 Dense(100, activation="relu"),
 Dense(10, activation="softmax")
])

# %%
optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(
 optimizer=optimizer, 
 loss="sparse_categorical_crossentropy", 
 metrics=["accuracy"]
)
model.summary()
# Out:
# Model: "sequential"
# Model: "sequential"
# _________________________________________________________________
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#  D)
#
#
#  flatten (Flatten)           (None, 5408)              0
#  flatten (Flatten)           (None, 5408)              0
#
#
#  dense (Dense)               (None, 100)               540900
#
#  dense (Dense)               (None, 100)               540900
#
#  dense_1 (Dense)             (None, 10)                1010
#  dense_1 (Dense)             (None, 10)                1010
#
#
# =================================================================
# =================================================================
# Total params: 542230 (2.07 MB)
# Total params: 542230 (2.07 MB)
# Trainable params: 542230 (2.07 MB)
# Trainable params: 542230 (2.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# _________________________________________________________________

# %% [markdown]
# # Train the Model

# %%
history = model.fit(X_train, y_train,validation_data = (X_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# Epoch 1/10
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2337 - accuracy: 0.9296 - val_loss: 0.0947 - val_accuracy: 0.9702
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2337 - accuracy: 0.9296 - val_loss: 0.0947 - val_accuracy: 0.9702
# Epoch 2/10
# Epoch 2/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.0749 - accuracy: 0.9776 - val_loss: 0.0800 - val_accuracy: 0.9730
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.0749 - accuracy: 0.9776 - val_loss: 0.0800 - val_accuracy: 0.9730
# Epoch 3/10
# Epoch 3/10
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0473 - accuracy: 0.9854 - val_loss: 0.0541 - val_accuracy: 0.9817
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0473 - accuracy: 0.9854 - val_loss: 0.0541 - val_accuracy: 0.9817
# Epoch 4/10
# Epoch 4/10
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.0347 - accuracy: 0.9895 - val_loss: 0.0509 - val_accuracy: 0.9839
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.0347 - accuracy: 0.9895 - val_loss: 0.0509 - val_accuracy: 0.9839
# Epoch 5/10
# Epoch 5/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.0252 - accuracy: 0.9929 - val_loss: 0.0441 - val_accuracy: 0.9852
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.0252 - accuracy: 0.9929 - val_loss: 0.0441 - val_accuracy: 0.9852
# Epoch 6/10
# Epoch 6/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 0.0404 - val_accuracy: 0.9862
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 0.0404 - val_accuracy: 0.9862
# Epoch 7/10
# Epoch 7/10
# 1875/1875 [==============================] - 23s 13ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.0400 - val_accuracy: 0.9868
# 1875/1875 [==============================] - 23s 13ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.0400 - val_accuracy: 0.9868
# Epoch 8/10
# Epoch 8/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0453 - val_accuracy: 0.9864
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0453 - val_accuracy: 0.9864
# Epoch 9/10
# Epoch 9/10
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.0422 - val_accuracy: 0.9861
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.0422 - val_accuracy: 0.9861
# Epoch 10/10
# Epoch 10/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0434 - val_accuracy: 0.9867
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0434 - val_accuracy: 0.9867

# %%
plt.figure(figsize=(16, 10))
for i in range(20):
 image = random.choice(X_test).squeeze()
 digit = np.argmax(model.predict(image.reshape((1, 28, 28, 1)))[0], axis=-1)
 plot_digit(image, digit, plt, i)
plt.show()
# Out:
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step

# %%
predictions = np.argmax(model.predict(X_test), axis=-1)
accuracy_score(y_test, predictions)
# Out:
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 2s 5ms/step
# 0.9867
# 0.9867

# %% [markdown]
# # Estimating the model's performance

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])    #Test Loss
print('Test accuracy:', score[1])    #Test Accuracy
# Out:
# Test loss: 0.043420638889074326
# Test accuracy: 0.9866999983787537
# Test loss: 0.043420638889074326
# Test accuracy: 0.9866999983787537

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = 10
epochs_range = range(epochs)

# %%
import os
# plotting the metrics
fig = plt.figure()
plt.figure(figsize=(8, 8))

plt.subplot(2,1,1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')


plt.subplot(2,1,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.tight_layout()

# %%
#Save the model
# serialize model to JSON
model_digit_json = model.to_json()
with open("model_digit.json", "w") as json_file:
 json_file.write(model_digit_json)
# serialize weights to HDF5
model.save_weights("model_digit.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
